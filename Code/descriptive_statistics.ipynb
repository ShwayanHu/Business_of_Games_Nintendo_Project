# %%
import numpy as np
import pandas as pd

from scipy.stats import zscore

# %%
original_data = pd.read_csv('Genshin_impact.csv',index_col=0,parse_dates=True)
original_data
# Out:
#             Android DAU  Apple DAU  Android installs  Apple installs  \
# event_date
# 2020-02-01     354409.6   323929.8           48552.0         24929.1
# 2020-02-02     326624.0   311472.0           47260.5         25720.2
# 2020-02-03     300012.8   280233.0           35532.0         19739.7
# 2020-02-04     298281.6   275931.9           35969.5         18157.5
# 2020-02-05     296556.8   273461.4           36820.0         17703.9
# ...                 ...        ...               ...             ...
# 2021-01-27     343158.4   205113.6           50197.0         11615.4
# 2021-01-28     348000.0   204533.1           55793.5         12271.5
# 2021-01-29     351369.6   214814.7           56983.5         12549.6
# 2021-01-30     366406.4   228546.9           61894.0         15535.8
# 2021-01-31     368416.0   221211.0           62198.5         14890.5
#
#             Android IAP  Apple iAP
# event_date
# 2020-02-01     248952.0  509254.40
# 2020-02-02     103620.0  283522.80
# ...

# %%
print(round(zscore(original_data).describe().T,2).to_latex())
# Out:
# \begin{tabular}{lrrrrrrrr}
# \toprule
# {} &  count &  mean &  std &   min &   25\% &   50\% &   75\% &    max \\
# \midrule
# Android DAU      &  366.0 &   0.0 &  1.0 & -1.44 & -0.65 & -0.27 &  0.35 &   3.76 \\
# Apple DAU        &  366.0 &   0.0 &  1.0 & -1.53 & -0.84 & -0.03 &  0.64 &   4.57 \\
# Android installs &  366.0 &   0.0 &  1.0 & -0.97 & -0.53 & -0.26 &  0.13 &   5.88 \\
# Apple installs   &  366.0 &   0.0 &  1.0 & -1.34 & -0.62 & -0.14 &  0.35 &  10.10 \\
# Android IAP      &  366.0 &  -0.0 &  1.0 & -1.12 & -0.63 & -0.27 &  0.31 &   6.42 \\
# Apple iAP        &  366.0 &  -0.0 &  1.0 & -1.13 & -0.66 & -0.26 &  0.33 &   6.70 \\
# \bottomrule
# \end{tabular}
# ...

# %%
print(round(zscore(original_data).skew(),2).to_latex())
# Out:
# \begin{tabular}{lr}
# \toprule
# {} &     0 \\
# \midrule
# Android DAU      &  1.52 \\
# Apple DAU        &  0.75 \\
# Android installs &  3.05 \\
# Apple installs   &  3.71 \\
# Android IAP      &  2.67 \\
# Apple iAP        &  2.95 \\
# \bottomrule
# \end{tabular}
# /var/folders/7l/j9np0sbx1b33249mt44v25980000gn/T/ipykernel_7531/3163820212.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(round(zscore(original_data).skew(),2).to_latex())

# %%
print(round(zscore(original_data).kurt(),2).to_latex())
# Out:
# \begin{tabular}{lr}
# \toprule
# {} &      0 \\
# \midrule
# Android DAU      &   2.41 \\
# Apple DAU        &   0.88 \\
# Android installs &  11.29 \\
# Apple installs   &  30.66 \\
# Android IAP      &  10.63 \\
# Apple iAP        &  13.45 \\
# \bottomrule
# \end{tabular}
# /var/folders/7l/j9np0sbx1b33249mt44v25980000gn/T/ipykernel_7531/3504883746.py:1: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   print(round(zscore(original_data).kurt(),2).to_latex())

# %%
original_data.corr()
# Out:
#                   Android DAU  Apple DAU  Android installs  Apple installs  \
# Android DAU          1.000000   0.566591          0.861227        0.357490
# Apple DAU            0.566591   1.000000          0.474566        0.757857
# Android installs     0.861227   0.474566          1.000000        0.430175
# Apple installs       0.357490   0.757857          0.430175        1.000000
# Android IAP          0.101903   0.088923          0.068217        0.092514
# Apple iAP            0.095648   0.143246          0.046682        0.112941
#
#                   Android IAP  Apple iAP
# Android DAU          0.101903   0.095648
# Apple DAU            0.088923   0.143246
# Android installs     0.068217   0.046682
# Apple installs       0.092514   0.112941
# Android IAP          1.000000   0.940839
# Apple iAP            0.940839   1.000000

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

sns.heatmap(original_data.corr(),annot=True,vmax=True,square=True,cmap='Blues')
plt.show()

# %%
data = pd.read_csv('Genshin_Impact_monthly.csv',parse_dates=True,index_col=0)
data
# Out:
#               Android DAU      Apple DAU  Android installs  Apple installs  \
# event_date
# 2020-02-29  319618.648276  295615.458621         1250609.5        688867.2
# 2020-03-31  429316.541935  305261.303226         2594833.5        697877.1
# 2020-04-30  413043.093333  277208.730000         1957455.5        541344.6
# 2020-05-31  376833.445161  270917.129032         1674760.5        576225.9
# 2020-06-30  350617.386667  260290.530000         1402005.5        556896.6
# 2020-07-31  392962.787097  258283.480645         2174819.5        574230.6
# 2020-08-31  353379.612903  236682.609677         1351101.5        460282.5
# 2020-09-30  351057.920000  233996.400000         1491273.0        518853.6
# 2020-10-31  327436.077419  218535.909677         1337903.0        393292.8
# 2020-11-30  324685.120000  220362.480000         1340563.0        456799.5
# 2020-12-31  329242.735484  215694.464516         1393318.5        457029.0
# ...

# %%
result = pd.read_csv('AR_prediction.csv',index_col=0,parse_dates=True)
print(result.round(2).to_latex())
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &  Android DAU(pct) &  Apple DAU(pct) &  Android\_installs(f) &  Apple\_installs(f) &  Android\_IAP(f) &  Apple\_IAP(f) \\
# \midrule
# 2021-02-28 &         314304.13 &       204375.41 &           1459324.07 &          468633.04 &      2725699.93 &    6226565.92 \\
# 2021-03-31 &         349070.76 &       210047.44 &           1556604.65 &          476956.96 &      2804281.05 &    6870181.70 \\
# 2021-04-30 &         343461.30 &       206795.86 &           1497907.04 &          481738.60 &      2775799.98 &    7153577.02 \\
# 2021-05-31 &         349218.70 &       208659.88 &           1526881.73 &          484485.39 &      2716991.41 &    6986026.43 \\
# 2021-06-30 &         334194.86 &       207591.30 &           1510656.38 &          486063.27 &      2691630.27 &    6664903.72 \\
# 2021-07-31 &         346027.30 &       208203.88 &           1519040.81 &          486969.68 &      2704127.04 &    6501609.23 \\
# ...
